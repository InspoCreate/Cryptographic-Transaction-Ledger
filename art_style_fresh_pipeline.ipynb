# %% [markdown]
# <a href="https://colab.research.google.com/github/InspoCreate/Cryptographic-Transaction-Ledger/blob/main/art_style_fresh_pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
